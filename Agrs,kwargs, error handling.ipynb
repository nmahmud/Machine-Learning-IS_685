# %% [markdown]
# args

# %%
def bunch_of_words(*args): # *args lets Python know you're planning to put in a currently undefined amount of arguments
    
    some_string = " " # This defines an empty string
    
    print(args)
    for a in args:
        some_string += ', '+ a
    
    return some_string

bunch_of_words('first_word', 'second_word', 'etc...', 'Pancakes')
# Out:
# ('first_word', 'second_word', 'etc...', 'Pancakes')
# ' , first_word, second_word, etc..., Pancakes'

# %%
def bunch_of_dict(**kwargs):
    
    for k, v in kwargs.items():
        print(k+ " : "+v)
        
    print('living happily')
bunch_of_dict(Institue='Family',Husband='Niaz',Wife='Sam')
# Out:
# Institue : Family
# Husband : Niaz
# Wife : Sam
# living happily

# %%
from scipy.stats import binom

# Calculate Binomial Example from above using Python
binom.pmf(k =0, n = 10, p = .7)
# Out:
# 5.904900000000006e-06

# %%
from scipy.stats import binom

# Calculate Binomial Example from above using Python
binom.pmf(k =0, n = 10, p = .7)+binom.pmf(k =1, n = 10, p = .7)
# Out:
# 0.0001436859000000004

# %%
from scipy.stats import binom

# Calculate Binomial Example from above using Python
1-binom.pmf(k =0, n = 10, p = .7)-binom.pmf(k =1, n = 10, p = .7)
# Out:
# 0.9998563141000001

# %%
from scipy.stats import poisson
poisson.pmf(k=5,mu=4)
# Out:
# 0.1562934518505317

# %%
from scipy.stats import norm
dist=norm(0,1).cdf(1)
print(dist)
# Out:
# 0.8413447460685429

# %%
from scipy.stats import norm
norm(0,1).cdf(3)
# Out:
# 0.9986501019683699

# %%
import math
sqrt=math.sqrt(100)
(50.3-50)/(1/sqrt)
# Out:
# 2.9999999999999716
